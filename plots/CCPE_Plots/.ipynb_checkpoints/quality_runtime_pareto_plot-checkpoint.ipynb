# %%
# !pip install pandas matplotlib gdown
# Out:
# Requirement already satisfied: pandas in /home/diogoocv/miniconda3/envs/SMAC/lib/python3.10/site-packages (2.3.3)
# Requirement already satisfied: matplotlib in /home/diogoocv/miniconda3/envs/SMAC/lib/python3.10/site-packages (3.10.8)
# Collecting gdown
#   Using cached gdown-5.2.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: numpy>=1.22.4 in /home/diogoocv/miniconda3/envs/SMAC/lib/python3.10/site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/diogoocv/miniconda3/envs/SMAC/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/diogoocv/miniconda3/envs/SMAC/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/diogoocv/miniconda3/envs/SMAC/lib/python3.10/site-packages (from pandas) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/diogoocv/miniconda3/envs/SMAC/lib/python3.10/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/diogoocv/miniconda3/envs/SMAC/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/diogoocv/miniconda3/envs/SMAC/lib/python3.10/site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/diogoocv/miniconda3/envs/SMAC/lib/python3.10/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /home/diogoocv/miniconda3/envs/SMAC/lib/python3.10/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /home/diogoocv/miniconda3/envs/SMAC/lib/python3.10/site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in /home/diogoocv/miniconda3/envs/SMAC/lib/python3.10/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: beautifulsoup4 in /home/diogoocv/miniconda3/envs/SMAC/lib/python3.10/site-packages (from gdown) (4.14.3)
# Collecting filelock (from gdown)
#   Downloading filelock-3.25.2-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: requests[socks] in /home/diogoocv/miniconda3/envs/SMAC/lib/python3.10/site-packages (from gdown) (2.33.0)
# Collecting tqdm (from gdown)
#   Downloading tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: six>=1.5 in /home/diogoocv/miniconda3/envs/SMAC/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: soupsieve>=1.6.1 in /home/diogoocv/miniconda3/envs/SMAC/lib/python3.10/site-packages (from beautifulsoup4->gdown) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/diogoocv/miniconda3/envs/SMAC/lib/python3.10/site-packages (from beautifulsoup4->gdown) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/diogoocv/miniconda3/envs/SMAC/lib/python3.10/site-packages (from requests[socks]->gdown) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /home/diogoocv/miniconda3/envs/SMAC/lib/python3.10/site-packages (from requests[socks]->gdown) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in /home/diogoocv/miniconda3/envs/SMAC/lib/python3.10/site-packages (from requests[socks]->gdown) (2.5.0)
# Requirement already satisfied: certifi>=2023.5.7 in /home/diogoocv/miniconda3/envs/SMAC/lib/python3.10/site-packages (from requests[socks]->gdown) (2026.2.25)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /home/diogoocv/miniconda3/envs/SMAC/lib/python3.10/site-packages (from requests[socks]->gdown) (1.7.1)
# Using cached gdown-5.2.1-py3-none-any.whl (18 kB)
# Downloading filelock-3.25.2-py3-none-any.whl (26 kB)
# Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, filelock, gdown
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [gdown]
# Successfully installed filelock-3.25.2 gdown-5.2.1 tqdm-4.67.3

# %%
import pandas as pd
import matplotlib.pyplot as plt
import gdown
import os

# %%
# Download data from Google Sheets using gdown
sheet_id = '1e_lKct9ovnYByYkGpFCKrMpKQs5TQdKhTld9tDU1JcQ'
gid_baseline = '1387240715' 
gid_fractal = '1558614809'
url_baseline = f'https://docs.google.com/spreadsheets/d/{sheet_id}/export?format=csv&gid={gid_baseline}'
url_fractal = f'https://docs.google.com/spreadsheets/d/{sheet_id}/export?format=csv&gid={gid_fractal}'

baseline_csv = 'baseline_data.csv'
fractal_csv = 'fractal_data.csv'

# Download files if they don't exist in the current directory
if not os.path.exists(baseline_csv):
    gdown.download(url_baseline, baseline_csv, quiet=False)
if not os.path.exists(fractal_csv):
    gdown.download(url_fractal, fractal_csv, quiet=False)
# Out:
# /home/diogoocv/miniconda3/envs/SMAC/lib/python3.10/site-packages/gdown/parse_url.py:48: UserWarning: You specified a Google Drive link that is not the correct link to download a file. You might want to try `--fuzzy` option or the following url: https://drive.google.com/uc?id=None
#   warnings.warn(
# Downloading...
# From: https://docs.google.com/spreadsheets/d/1e_lKct9ovnYByYkGpFCKrMpKQs5TQdKhTld9tDU1JcQ/export?format=csv&gid=1387240715
# To: /home/diogoocv/VSCode/smac3/baseline_data.csv
# 1.34kB [00:00, 2.46MB/s]
# Downloading...
# From: https://docs.google.com/spreadsheets/d/1e_lKct9ovnYByYkGpFCKrMpKQs5TQdKhTld9tDU1JcQ/export?format=csv&gid=1558614809
# To: /home/diogoocv/VSCode/smac3/fractal_data.csv
# 24.8kB [00:00, 45.9MB/s]

# %%
# 2. Load the data
df_baseline = pd.read_csv(baseline_csv)
df_fractal = pd.read_csv(fractal_csv)

# Clean up column names to match the exact headers you provided
df_baseline.columns = df_baseline.columns.astype(str).str.strip().str.lower().str.replace(' ', '_')
df_fractal.columns = df_fractal.columns.astype(str).str.strip().str.lower().str.replace(' ', '_')

# Drop any duplicated columns caused by the Pivot Table export
df_baseline = df_baseline.loc[:, ~df_baseline.columns.duplicated()]
df_fractal = df_fractal.loc[:, ~df_fractal.columns.duplicated()]

# Clean up stray unnamed columns from the spreadsheet export
df_fractal = df_fractal.loc[:, ~df_fractal.columns.str.contains('unnamed')]

# 3. Define mapping (no more configuration filter!)
baseline_mapping = {
    'densesubgraph': 'Greedy Peeling (Greedy++)',
    'triangledensestsubgraph': 'Triangle Densest Batch Peeling'
}

# We use the full dataset now to plot all 9 configurations
df_fractal_filtered = df_fractal.copy()

# Sort by time so the lines draw correctly from left to right on the plot
df_fractal_filtered.sort_values(by=['graph_name', 'objective_function', 'metaheuristic', 'average_of_total_time_ms'], inplace=True)

# Define standard styling
graphs = ['amazon', 'citeseer', 'dblp', 'livejournal', 'patents', 'youtube']
metaheuristics = df_fractal_filtered['metaheuristic'].unique()
colors = {'vns': '#1f77b4', 'ils': '#ff7f0e', 'ts1': '#2ca02c'}
markers = {'vns': 'o', 'ils': 's', 'ts1': '^'}

# 4. Generate the plots
for obj_func, baseline_alg in baseline_mapping.items():
    fig, axes = plt.subplots(2, 3, figsize=(18, 10))
    fig.suptitle(f'Normalized Pareto Front: {obj_func}', fontsize=18, weight='bold')
    axes = axes.flatten()
    
    for i, graph in enumerate(graphs):
        ax = axes[i]
        ax.set_title(f'Graph: {graph}')
        ax.set_xlabel('Total Time (ms) - Log Scale')
        ax.set_ylabel('Normalized Score (Fractal / Baseline)')
        
        # Use log scale for X due to massive differences in runtime
        ax.set_xscale('log') 
        
        # Plot Baseline
        baseline_data = df_baseline[(df_baseline['objective_function'] == obj_func) & 
                                    (df_baseline['algorithm'] == baseline_alg) & 
                                    (df_baseline['graph'] == graph)]
        
        if not baseline_data.empty:
            # Extract Baseline score and time
            baseline_score = baseline_data['cost_best_solution'].values[0]
            baseline_time = baseline_data['total_time_(ms)'].values[0]
            
            # Plot Baseline at exactly Y = 1.0
            ax.scatter(baseline_time, 
                       1.0, 
                       color='red', marker='*', s=250, label=f'Baseline ({baseline_alg})', zorder=5)
            
            # Plot Metaheuristics
            for meta in metaheuristics:
                meta_data = df_fractal_filtered[(df_fractal_filtered['objective_function'] == obj_func) & 
                                                (df_fractal_filtered['metaheuristic'] == meta) & 
                                                (df_fractal_filtered['graph_name'] == graph)]
                
                if not meta_data.empty:
                    # Normalize the score!
                    normalized_score = meta_data['average_of_cost_best_solution'] / baseline_score
                    
                    ax.plot(meta_data['average_of_total_time_ms'], 
                            normalized_score, 
                            color=colors.get(meta, 'black'), 
                            marker=markers.get(meta, 'o'), 
                            markersize=8, 
                            linestyle='-', 
                            linewidth=2,
                            label=f'Fractal - {meta.upper()}')
        
        ax.grid(True, which="both", ls="--", alpha=0.5)
        
        # Add legend only to the first subplot
        if i == 0:  
            ax.legend(loc='best', fontsize='small')

    plt.tight_layout(rect=[0, 0.03, 1, 0.95])
    plt.savefig(f'pareto_front_{obj_func}.png', dpi=300, bbox_inches='tight')
    plt.show()
